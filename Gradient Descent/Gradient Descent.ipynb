# %%
import pandas as pd

# %%
df = pd.read_csv("Placement.csv")

# %%
df
# Out:
#     cgpa  package
# 0   6.89     3.26
# 1   5.12     1.98
# 2   7.82     3.25
# 3   7.42     3.67
# 4   6.94     3.57
# 5   7.89     2.99
# 6   6.73     2.60
# 7   6.75     2.48
# 8   6.09     2.31
# 9   8.31     3.51
# 10  5.32     1.86
# 11  6.61     2.60
# 12  8.94     3.65
# 13  6.93     2.89
# 14  7.73     3.42
# 15  7.25     3.23
# 16  6.84     2.35
# 17  5.38     2.09
# 18  6.94     2.98
